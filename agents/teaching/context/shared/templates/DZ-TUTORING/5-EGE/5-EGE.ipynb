# %% [markdown]
# #### Простые суммы
#
# 1) Запускаем цикл в необходимом для нас промежутке
#
# 		for i in range(100, 1000) #например число должно быть трехзначным
#
# 2) Переводим число в строку
#
# 		s = str(i)
#
# 3) Складываем необходимые цифры (по индексам, **у первого элемента индекс 0**)
#
# 		k1 = int(s[0]) + int(s[1])
# 		k2 = int(s[0]) + int(s[1])
# 		#например складываем 1 и 2, а также 2 и 3 цифры
#
# 4) Записываем полученные переменные друг за другом (в формате строки) в необходимом нам порядке.
#
# 		r = str(min(k1, k2)) + str(max(k1, k2))
# 		#например записываем их в порядке возростания (сначала min, потом max)
#
# 5) Производим необходимую проверку, и выводим нужную нам переменную: либо i - это начальное число (то, что подается на вход), либо r - конечное число (результат работы алгоритма). Если просят указать минимальное число - пишем break
#
# 		if int(r) == 1414:
# 		print(s)
# 		break
# 		#например нас просят указать минимальное число, в результате обработки которого автомат выдаст 1414
#
# ---
#
# № 1 Автомат получает на вход четырёхзначное десятичное число, в котором все цифры нечётные. По этому числу строится новое число по следующим правилам.
#
# 1.  Складываются первая и вторая, а также третья и четвёртая цифры.
#
# 2.  Полученные два числа записываются друг за другом в порядке неубывания (без разделителей).
#
#
# Сколько существует чисел, в результате обработки которых автомат выдаст число 616?

# %% [markdown]
# № 2 Автомат получает на вход трёхзначное число. По этому числу строится новое число по следующим правилам.
#
# 1.  Складываются отдельно первая и вторая цифры, а также вторая и третья цифры.
#
# 2.  Полученные два числа записываются друг за другом в порядке неубывания без разделителей.
#
#
# Укажите наименьшее число, при обработке которого автомат выдаёт результат 714.

# %% [markdown]
# № 3 Автомат получает на вход четырёхзначное число. По этому числу строится новое число по следующим правилам:
#
# 1.  Перемножаются первая и вторая, а также третья и четвёртая цифры исходного числа.
#
# 2.  Полученные два числа записываются друг за другом в порядке убывания (без разделителей).
#
#
#
# Укажите наименьшее число, в результате обработки которого автомат выдаст число 124.

# %% [markdown]
# #### Двоичная запись
#
# 1) Запускаем цикл в необходимом для нас промежутке
#
# 		for i in range(0, 10000) #если число должно быть натуральным
#
# 2) Переводим число в двоичную запись и обрезаем у него первые два символа
#
# 		s = bin(i)[2:]
#
# 3) Выполняем необходимые действия и меняем двоичную записью
#
# 		if n % 2 == 0:
# 		s += '11'
# 		#например дописать к двоичной записи "11", если число четное
#
# 4) Переводим запись обратно в десятичную СС
#
# 		r = int(s, 2)
#
# 5) Производим необходимую проверку, и выводим нужную нам переменную: либо i - это начальное число (то, что подается на вход), либо r - конечное число (результат работы алгоритма). Если просят указать минимальное число - пишем break
#
# 		if r == 1414:
# 		print(s)
# 		break
# 		#например нас просят указать минимальное число, в результате обработки которого автомат выдаст 1414
#
# ---
#
#
# № 4 На вход алгоритма подаётся натуральное число N. Алгоритм строит по нему новое число R следующим образом.
#
# 1.  Строится двоичная запись числа N.
#
# 2.  Далее эта запись обрабатывается по следующему правилу:
# а)  если число чётное, то к двоичной записи числа слева дописывается 1, а справа  — 0. Например, для исходного числа 1002 результатом будет являться число 11000;
# б)  если число нечётное, то к двоичной записи числа слева дописывается 11 и справа дописывается 11.
#
# Полученная таким образом запись является двоичной записью искомого числа R.
#
# Укажите минимальное число N, после обработки которого с помощью этого алгоритма получается число, большее, чем 52. В ответе запишите это число в десятичной системе счисления.

# %%
for i in range(0, 10000):
	s = bin(i)[2:]
	if i % 2 == 0:
		s = '1' + s + '0'
	else:
		s = '11' + s + '11'
	r = int(s, 2)
	if r > 52:
		print(i)
		break
# Out:
# 3

# %% [markdown]
# № 5 На вход алгоритма подаётся натуральное число N. Алгоритм строит по нему новое число следующим образом.
#
# 1)  Строится двоичная запись числа N.
#
# 2)  К этой записи дописываются справа ещё два разряда по следующему правилу: если N чётное, в конец числа (справа) дописываются два нуля, в противном случае справа дописываются две единицы. Например, двоичная запись 1001 числа 9 будет преобразована в 100111.
#
# Полученная таким образом запись (в ней на два разряда больше, чем в записи исходного числа N) является двоичной записью числа  — результата работы данного алгоритма.
# Укажите максимальное число N, для которого результат работы алгоритма будет меньше 134. В ответе это число запишите в десятичной системе счисления.

# %% [markdown]
# № 6 На вход алгоритма подаётся натуральное число  N . Алгоритм строит по нему новое число следующим образом:
#
# 1.	Строится двоичная запись числа  N .
#
# 2.	К этой записи дописываются справа ещё три разряда по следующему правилу:
# 	•	Если  N  чётное, в конец числа (справа) дописываются три нуля.
# 	•	Если  N  нечётное, в конец числа дописываются три единицы.
#
#
#
# Полученная таким образом запись (в ней на три разряда больше, чем в записи исходного числа  N ) является двоичной записью результата работы алгоритма.
#
#
# Укажите максимальное число  N , для которого результат работы алгоритма будет меньше 200. В ответе запишите это число в десятичной системе.

# %% [markdown]
# № 7 На вход алгоритма подаётся натуральное число  N . Алгоритм строит по нему новое число следующим образом:
#
# 1.	Строится двоичная запись числа  N .
#
# 2.	В начало этой записи дописываются два разряда по следующему правилу:
# 	•	Если  N  делится на 3, в начало записи дописываются «11».
# 	•	В противном случае дописываются «00».
#
#
# Полученная таким образом запись (в ней на два разряда больше, чем в записи исходного числа  N ) является двоичной записью результата работы алгоритма.
#
#
# Укажите максимальное число  N , для которого результат работы алгоритма будет меньше 120. В ответе запишите это число в десятичной системе.

# %% [markdown]
# № 8 На вход алгоритма подаётся натуральное число N. Алгоритм строит по нему новое число R следующим образом.
#
# 1.  Строится двоичная запись числа N.
#
# 2.  К этой записи дописываются справа ещё два разряда по следующему правилу:
# а)  складываются все цифры двоичной записи, и остаток от деления суммы на 2 дописывается в конец числа (справа). Например, запись 11100 преобразуется в запись 111001;
# б)  над этой записью производятся те же действия  — справа дописывается остаток от деления суммы цифр на 2.
#
# Полученная таким образом запись (в ней на два разряда больше, чем в записи исходного числа N) является двоичной записью искомого числа R.
#
# Укажите минимальное число R, которое превышает 43 и может являться результатом работы алгоритма. В ответе это число запишите в десятичной системе.

# %%
for i in range(0, 10000):
	s = bin(i)[2:]
	n = s.count('1') % 2
	s = s + str(n)
	n = s.count('1') % 2
	s = s + str(n)
	r = int(s, 2)
	if r > 43:
		print(r)
		break
# Out:
# 46

# %% [markdown]
# № 8 (сложная) Алгоритм получает на вход натуральное число N > 1 и строит по нему новое число R следующим образом.
#
# 1.  Строится двоичная запись числа N.
#
# 2.  Вместо последней (самой правой) двоичной цифры дважды записывается вторая слева цифра двоичной записи.
#
# 3.  Результат переводится в десятичную систему.
#
#
#
# При каком наименьшем числе N в результате работы алгоритма получится R > 76? В ответе запишите это число в десятичной системе счисления.
