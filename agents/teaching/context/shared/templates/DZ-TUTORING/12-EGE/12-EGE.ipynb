# %% [markdown]
# #### Простые операции
#
# 1) Записываем строку в переменную s
#
# 		s = '1' * 100
# 		#если строка должна состоять из ста цифр 1
#
# 2) Переписываем алгоритм с задачи, пока - while, что-то нашлось - 'что-то' in s, что-то не нашлось - 'что-то' not in s: заменить (что-то-одно, что-то-другое) - s = s.replace('что-то-одно', 'что-то-другое', 1), ЕСЛИ и ИНАЧЕ просто пропускаем, пишем только то, что внутри них. КОНЕЦ и все что с ним связанно также пропускаем
#
# 		ПОКА нашлось (11) или нашлось (22)
# 		ЕСЛИ нашлось (11)
# 		ТО заменить (11, 2)
# 		ИНАЧЕ заменить (22, 3)
#
# 		while '11' in s or '22' in s:
# 			s = s.replace('11', '2', 1)
# 			s = s.replace('22', '3', 1)
#
# 3) Выводим print(s) в конце, вне цикла
#
# 		s = ...
# 		while ...
# 			...
# 		print(s)
#
# ---
#
# №1 Какая строка получится в результате применения приведённой ниже программы к строке, состоящей из 108 идущих подряд цифр 7? В ответе запишите полученную строку.
#
# НАЧАЛО
#
# ПОКА нашлось (33333) ИЛИ нашлось (777)
#
# ЕСЛИ нашлось (33333)
#
# ТО заменить (33333, 7)
#
# ИНАЧЕ заменить (777, 3)
#
# КОНЕЦ ЕСЛИ
#
# КОНЕЦ ПОКА
#
# КОНЕЦ

# %%
s = '7' * 108
while '33333' in s or '777' in s:
	s = s.replace('33333', '7', 1)
	s = s.replace('777', '3', 1)
print(s)
# Out:
# 3337

# %% [markdown]
# №2 Ниже приведена программа для исполнителя Редактор.
#
# НАЧАЛО
#
# ПОКА нашлось (722) ИЛИ нашлось (557)
#
#   ЕСЛИ нашлось (722)
#
#     ТО заменить (722, 57)
#
#     ИНАЧЕ заменить (557, 72)
#
#   КОНЕЦ ЕСЛИ
#
# КОНЕЦ ПОКА
#
# КОНЕЦ
#
#
# На вход этой программе подается строка, состоящая из 55 цифр; последняя цифра в строке  — цифра 7, а остальные цифры  — пятёрки. Какая строка получится в результате применения программы к этой строке? В ответе запишите полученную строку.

# %% [markdown]
# №3 Какая строка получится в результате применения приведённой ниже программы к строке, состоящей из 77 единиц?
#
# НАЧАЛО
#
#     ПОКА нашлось (111)
#
#         заменить (111, 2)
#
#         заменить (222, 3)
#
#         заменить (333, 1)
#
#     КОНЕЦ ПОКА
#
# КОНЕЦ

# %% [markdown]
# #### Усложненные операции, с неизвестой начальной строкой
#
# 1) В задачах, где исходная строка неизвестна, нам нужно составить ее самостоятельно, при помощи циклов for (тут уже больше вариаций, покажу несколько из них)
#
# 		for i in range(200, 1000):
# 			s = '1' * i
# 			...
# 		#например строка должна состоять болле чем из двухсот цифр 1
#
# 		for i in range(20, 1000):
# 			for j in range(20, 1000):
# 				s = '0' + '2' * i + '3' * j + '0'
# 		#например строка должна начинаться и заканчиваться нулем, а между нулями должно быть более 20 троек и двоек
#
# 2) Переписываем алгоритм с задачи, пока - while, что-то нашлось - 'что-то' in s, что-то не нашлось - 'что-то' not in s: заменить (что-то-одно, что-то-другое) - s = s.replace('что-то-одно', 'что-то-другое', 1), ЕСЛИ и ИНАЧЕ просто пропускаем, пишем только то, что внутри них. КОНЕЦ и все что с ним связанно также пропускаем
#
# 		ПОКА нашлось (11) или нашлось (22)
# 		ЕСЛИ нашлось (11)
# 		ТО заменить (11, 2)
# 		ИНАЧЕ заменить (22, 3)
# 		for ...
# 			while '11' in s or '22' in s:
# 				s = s.replace('11', '2', 1)
# 				s = s.replace('22', '3', 1)
# 			...
#
# 3) Делаем необходимую проверку и выводим нужный ответ
#
# 		if s.count('2') == 0:
# 			print(i)
# 		#например нужно найти минимальное кол-во едениц в исходной строке, при котором после исполнения программы итоговая строка будет содержать только единицы - тут смотрим на все возможные символы внутри replace, допустим в нашем примере мы использовали только '2' и '1', и чтобы проверить, что в строке содержаться только единички, нам достаточно проверить, что в этой строке не содержатся двойки: s.count('2') == 0
#
# ---
#
# №4 Дана программа для редактора:
#
# НАЧАЛО
#
#     ПОКА нашлось (111) ИЛИ нашлось (222)
#
#         заменить (111, 22)
#
#         заменить (222, 1)
#
#     КОНЕЦ ПОКА
#
# КОНЕЦ
#
#
# Известно, что исходная строка содержала больше 200 единиц и не содержала других цифр, а после выполнения программы тоже получилась строка, содержащая только единицы. Какое наименьшее количество единиц могло быть в исходной строке?

# %%
for i in range(200, 1000):
	for j in range(100, 1000):
		s = '3' + i * '1' + j * '2'
		while '111' in s or '222' in s:
			s = s.replace('111', '22', 1)
			s = s.replace('222', '1', 1)
		if s.count('1') == len(s):
			print(i)
			break
# Out:
# 205

# %% [markdown]
# №5 На вход приведённой ниже программе поступает строка, начинающаяся с символа «>», а затем содержащая 11 цифр 1, 12 цифр 2 и 30 цифр 3, расположенных в произвольном порядке.
#
# Определите сумму числовых значений цифр строки, получившейся в результате выполнения программы.
#
#
# НАЧАЛО
#
# ПОКА нашлось (>1) ИЛИ нашлось (>2) ИЛИ нашлось (>3)
#
#     ЕСЛИ нашлось (>1)
#
#         ТО заменить (>1, 22>)
#
#     КОНЕЦ ЕСЛИ
#
#     ЕСЛИ нашлось (>2)
#
#         ТО заменить (>2, 2>)
#
#     КОНЕЦ ЕСЛИ
#
#     ЕСЛИ нашлось (>3)
#
#         ТО заменить (>3, 1>)
#
#     КОНЕЦ ЕСЛИ
#
# КОНЕЦ ПОКА
#
# КОНЕЦ
