# %% [markdown]
# 1) Пусть есть переменная num. Нужно определить, является ли число чётным или нечётным.

# %% [markdown]
# 2) Есть переменная number. Нужно найти сумму его цифр. (number = 1234, сумма его цифр = 10)

# %% [markdown]
# 3) Дано число N. Нужно вывести все числа от 1 до N (включительно) через пробел. (N = 5, вывод: 1 2 3 4 5)

# %% [markdown]
# 4) Есть переменная num. Нужно найти наибольшую цифру в этом числе и вывести её. (num = 14723, вывод: 7)
